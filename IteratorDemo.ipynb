# %%
scores=[1,5,7]

# %%
si=iter(scores)

# %%
print(next(si))
# Out:
# 1

# %%
print(next(si))
# Out:
# 5

# %%
print(next(si))
# Out:
# 7

# %%
print(next(si)) #Error as there are no more values
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(next(si))
#
# StopIteration:

# %%
name="Tia"

# %%
n=iter(name)

# %%
next(n)
# Out:
# 'T'
